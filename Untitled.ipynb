# %%
from platform import python_version
import os,sys

# %%
python_version()
# Out:
# '3.9.16'

# %%
cmd = "export PATH='/notebooks/notebooks/pythontest/bin:$PATH'"
os.system()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 2
#       1 cmd = "export PATH='/notebooks/notebooks/pythontest/bin:$PATH'"
# ----> 2 sys.executable(cmd)
#
# TypeError: 'str' object is not callable

# %%
python_version()
# Out:
# '3.9.16'
