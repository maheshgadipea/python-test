# %%
from platform import python_version
import os,sys

# %%
python_version()
# Out:
# '3.9.16'

# %%
# cmd = "export PATH='/notebooks/notebooks/pythontest/bin:$PATH'"
sys.path.insert(0,"/notebooks/notebooks/pythontest/bin")

# %%
python_version()
# Out:
# '3.9.16'
